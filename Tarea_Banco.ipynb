# %% [markdown]
# <a href="https://colab.research.google.com/github/LuffiNeil/UTEC-PHYTON/blob/main/Tarea_Banco.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
income = 0
payment_history = False
client_type = ''
det_total = 0

def Det_Calculation (det_count):
  global det_total
  z = 0
  while (z != det_count):
    det_total = det_total + int(input('ingrese el valor '))
    z += 1
  return det_total

cliente_name = input ('Ingrese nombre del cliente ')

print ('El cliente tiene deudas pendientes?')
det_confirmation = bool(input(' Indique si cuenta con deudas '))
if(det_confirmation == True):
    print('cuantas dedudas cuenta el cliente')
    x = int(input('Ingrse el numero de deudas '))
    Det_Calculation(x)
    payment_history = bool(input(' Indique si el cliente ah cumplido con el pago de sus cuotas mensuales'))
else:
    print ('No cuenta con deudas')
# Out:
# Ingrese nombre del cliente Ithan
# El cliente tiene deudas pendientes?
#  Marque si cuenta con deudas Si
# cuantas dedudas cuenta el cliente
# Ingrse el numero de deudas 1
# ingrese el valor1500
# 1500
