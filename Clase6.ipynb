# %% [markdown]
# <a href="https://colab.research.google.com/github/LuffiNeil/UTEC-PHYTON/blob/main/Clase6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
balance = 100

while balance > 0:
  withdrawal = int(input('Retiro (0 para salir): '))
  if withdrawal == 0:
    break
  elif withdrawal > balance:
    print('Saldo no disponible')
    continue
  else:
    balance -= withdrawal

def CheckingWithdrawal(ammount):
  if ammount <0:
    ammount = int(input('Valor incorrecto ingrese un momento positivo '))


print('Fin. Saldo: ', balance)
# Out:
# Retiro (0 para salir): 50
# Retiro (0 para salir): 0
# Fin. Saldo:  50

# %%
def Calculator ():
  number = 100 * 5
  return number

Calculator()
# Out:
# 500

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
def Annual_income(mounthly_income):
  return mounthly_income * 12

Annual_income(1300)
# Out:
# 15600

# %%
def CPC (spent,clics):
  if clics == 0:
    return print('Calculo imposible el valor de clics es  ',clics)
  else:
    return print('El CPC es el siguiente ',round(spent/clics,2))

CPC(1000,50)
# Out:
# El CPc es el siguiente  20.0

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
def concat_ws(sep,*words):
  return sep.join(words)

concat_ws(' ','come','arroz','todos','los ','dias')
# Out:
# 'come arroz todos los  dias'

# %%
def def_options(**options):
  return options

def_options(option1="playa",option2="pradera")
# Out:
# {'option1': 'playa', 'option2': 'pradera'}
