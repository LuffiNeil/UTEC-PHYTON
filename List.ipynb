# %% [markdown]
# <a href="https://colab.research.google.com/github/LuffiNeil/UTEC-PHYTON/blob/main/List.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class Client:
    name = ""
    age = 0
    income = 0
    def __init__(self,name,age,income):
        self.name = name
        self.age = age
        self.income = income


client_list = []

client_list.append(Client('Ithan',27,1300))

print(type(client_list))
print(client_list[0].name)
# Out:
# <class 'list'>
# Ithan

# %%
classmate = ['Juan','Jesus','stephany','Jhair','Gustavo']

classmate.append('Ithan')

classmate
# Out:
# ['Juan', 'Jesus', 'stephany', 'Jhair', 'Gustavo', 'Ithan']

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
client_info = {
    'name' : 'Ariel',
    'lastname': 'Medina',
    'age' : 25,
    'job' : 'actor',
    'income' : 2300,
}

campein_info = {
    'name' : 'Lanzamiento verano',
    'channles' : ["Facebook","Instagran","tiktok"],
    'valance' : 1000
}

credit_info = {
    'client_name' : 'Luis',
    'detail' : {
        'value' : 5000,
        "time" : 12,
        'taza' : 22
    }
}

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
client_info ={
    'name' : 'Pedro',
    'income' : 6000,
    'actual_det' : 2000,
    'det_history' : {
        'past_det1' : {'value':3000,'status': 'paid'},
        'past_det2' : {'value':5600,'status': 'paid'}
    },
    'credit_score' : 'good'
}

client_info

# %%
clients_dict = {
    'client1' : {
        'name' : 'Juan',
        'income' : 1500
    },
    'client2' : {
        'name' : 'Pedro',
        'income' : 2000
    },
    'client3' : {
        'name' : 'Maria',
        'income' : 1000
    }
}
